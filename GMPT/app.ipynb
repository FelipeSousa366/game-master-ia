# %%
import os
from openai import OpenAI
import openai

# Configuração do cliente OpenAI
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def chat_com_mestre(mensagem_jogador, contexto=""):
    """
    Função para enviar uma mensagem ao chatbot e receber uma resposta.
    
    :param mensagem_jogador: A mensagem do jogador.
    :param contexto: Contexto adicional para o chatbot (opcional).
    :return: Resposta do chatbot.
    """
    try:
        resposta = client.chat.completions.create(
            model="gpt-4o",  # Modelo a ser usado
            messages=[
                {"role": "system", "content": f"""Você é um Mestre de RPG experiente em Dungeons & Dragons. Seja criativo e siga as regras.
                Ficha do jogador
                Nome do personagem: {nome} 
                Classe: {classe}
                Origem: {origem}
                Nivel: 1
                """},
                {"role": "user", "content": f"{contexto}\nJogador: {mensagem_jogador}"}
            ],
            max_tokens=500,  # Limite de tokens na resposta
            temperature=1,  # Controle de criatividade (0 = mais determinístico, 1 = mais criativo)
        )
        return resposta.choices[0].message.content.strip()
    except Exception as e:
        return f"Erro ao conectar com a API: {e}"

# Exemplo de uso

# %%
def gerar_imagem(descricao, num_imagens=1, tamanho="1024x1024"):
    try:
        resposta = client.images.generate(
            model="dall-e-3",  # Especifica o modelo DALL-E 3
            prompt=descricao,   # Descrição da imagem que você deseja gerar
            n=num_imagens,      # Número de imagens a serem geradas
            size=tamanho        # Tamanho da imagem (opções: "1024x1024", "1024x1792", "1792x1024")
        )
        # Retorna as URLs das imagens geradas
        return [imagem.url for imagem in resposta.data]
    except Exception as e:
        print(f"Erro ao gerar a imagem: {e}")
        return None

# %%
if __name__ == "__main__":
    
    print ("Vamos começar montando sua ficha")
    nome = input("Qual seu nome?")
    classe = input("Qual sua classe?")
    origem = input("Qual sua origem?")
    aparencia = input("Qual a aparência do seu personagem?")
    contexto = input("O que seu personagem está fazendo? Onde ele está?")
    
    inicio = client.chat.completions.create(
            model="gpt-4o",  # Modelo a ser usado
            messages=[
                {"role": "system", "content": f"""Você é um Mestre de RPG experiente em Dungeons & Dragons. Seja criativo e siga as regras.
                Ficha do jogador
                Nome do personagem: {nome} 
                Classe: {classe}
                Origem: {origem}
                Nivel: 1
                """},
                {"role": "user", "content": f"""Dê detalhes sobre a ficha do jogador de forma mais tecnica Exemplo:
                Ficha de Personagem - D&D 5ª Edição

Nome do Personagem:
Classe e Nível:
Raça:
Antecedente:
Tendência:
Experiência (XP):

Atributos:

Força (For):

Destreza (Des):

Constituição (Con):

Inteligência (Int):

Sabedoria (Sab):

Carisma (Car):

Pontos de Vida (PV):
Classe de Armadura (CA):
Iniciativa:
Deslocamento:

Testes de Resistência:

Força:

Destreza:

Constituição:

Inteligência:

Sabedoria:

Carisma:


Perícias:



Idiomas:

Equipamento:

Características e Talentos de Classe:

Magias (se aplicável):

Classe de Magia:

CD para resistir às magias:

Bônus de Ataque Mágico:

Espaços de Magia:


Magias Conhecidas/Preparadas:



História do Personagem:
                , e no fim inicie a aventura com base no contexto: {contexto}"""}
            ],
            max_tokens=1000,  # Limite de tokens na resposta
            temperature=1,  # Controle de criatividade (0 = mais determinístico, 1 = mais criativo)
        )
# Out:
# Vamos começar montando sua ficha
# Qual seu nome? Akashi
# Qual sua classe? Mago
# Qual sua origem? Acolito
# Qual a aparência do seu personagem? Um jovem de cabelos vermelhos e olhar reluzente
# O que seu personagem está fazendo? Onde ele está? Está na academia de magia

# %%
print (inicio.choices[0].message.content.strip())
while True:
        mensagem_jogador = input(f"\n{nome}: ")
        if mensagem_jogador.lower() in ["sair", "exit"]:
            print("Até logo, aventureiro!")
            break
        if mensagem_jogador.lower() == "!aparencia":
            aparencia_imagem = gerar_imagem (aparencia, num_imagens=1, tamanho="1024x1024")

            if aparencia_imagem:
                for i, url in enumerate(aparencia_imagem):
                    print(f"Imagem {i+1}: {url}")
            else:
                print("Nenhuma imagem foi gerada.")

        elif mensagem_jogador.lower() == "!cena":
            prompt_imagem = client.chat.completions.create(
            model="gpt-4o",  # Modelo a ser usado
            messages=[
                {"role": "system", "content": f"""Você é um especialista em prompt de imagens especializado em Dall-e-3, você deve criar o melhor prompt
                possível para geração de imagem baseado no contexto fornecido. seja breve e claro
                """},
                {"role": "user", "content": f"""Crie um prompt para criação de imagem baseado no contexto: {contexto}
                em caso de {nome} ser citado utilize sua aparencia: {aparencia}
                """}
            ],
            max_tokens=100,  # Limite de tokens na resposta
            temperature=0.7,  # Controle de criatividade (0 = mais determinístico, 1 = mais criativo)
        )


            prompt_imagem_clear = prompt_imagem.choices[0].message.content.strip()

            """print (prompt_imagem_clear)"""

            contexto_imagem = gerar_imagem (prompt_imagem_clear, num_imagens=1, tamanho="1024x1024")



            if contexto_imagem:
                for i, url in enumerate(contexto_imagem):
                    print(f"Imagem {i+1}: {url}")
            else:
                print("Nenhuma imagem foi gerada.")   

        else:
            resposta = chat_com_mestre(mensagem_jogador, contexto)
            contexto= resposta
            print(f"\nMestre: {resposta}\n")
# Out:
# **Ficha de Personagem - D&D 5ª Edição**
#
# **Nome do Personagem:** Akashi
# **Classe e Nível:** Mago, 1
# **Raça:** Humano
# **Antecedente:** Acólito
# **Tendência:** Neutro Bom
# **Experiência (XP):** 0
#
# **Atributos:**
#
# - **Força (For):** 8 (-1)
# - **Destreza (Des):** 14 (+2)
# - **Constituição (Con):** 12 (+1)
# - **Inteligência (Int):** 16 (+3)
# - **Sabedoria (Sab):** 13 (+1)
# - **Carisma (Car):** 10 (+0)
#
# **Pontos de Vida (PV):** 6
# **Classe de Armadura (CA):** 12 (10 + Mod. Dex)
# **Iniciativa:** +2
# **Deslocamento:** 9 metros
#
# **Testes de Resistência:**
#
# - **Força:** -1
# - **Destreza:** +2
# - **Constituição:** +1
# - **Inteligência:** +5 (Proficiente)
# - **Sabedoria:** +3 (Proficiente)
# - **Carisma:** +0
#
# **Perícias:**
#
# - Religião (+5)
# - Arcanismo (+5)
# - História (+5)
# - Intuição (+3)
#
# **Idiomas:** Comum, Élfico, Celestial
#
# **Equipamento:**
#
# - Cajado
# - Livro de Magias
# - Kit de Explorador
# - Símbolo sagrado
# - Roupas comuns
# - 15 po
#
# **Características e Talentos de Classe:**
#
# - Recuperação Arcana: Recupera 1 slot de feitiço/descanso
#
# **Magias:**
#
# **Classe de Magia:** Inteligência
# **CD para resistir às magias:** 13
# **Bônus de Ataque Mágico:** +5
# **Espaços de Magia:** 2 Espaços de 1º Nível
#
# **Magias Conhecidas/Preparadas:**
#
# - **Truques:** Luz, Prestidigitação, Raio de Fogo
# - **Magias de 1º Nível:** Mísseis Mágicos, Escudo Arcano, Compreensão de Idiomas
#
# **História do Personagem:**
#
# Akashi nasceu em uma vila humilde e foi criado por sacerdotes em um templo dedicado ao aprendizado e à sabedoria. Desde jovem, ele demonstrou uma afinidade natural para a magia, o que o levou a ser enviado para a prestigiosa Academia de Magia Arcanis. Aqui, ele se aprofunda nos arcanos, tentando entender o equilíbrio entre a fé que aprendeu no templo e o poder bruto da magia.
#
# ---
#
# **Início da Aventura:**
#
# Na luminosa manhã na Academia de Magia Arcanis, os novos iniciados são despertados pelo som melódico de sinos ressoando pelas antigas paredes. Akashi, ansioso e carregando seu grimório sob o braço, dirige-se ao seu primeiro dia de aulas avançadas. Passando por corredores repletos de estudantes e professores discutindo encantamentos, ele sente o ar vibrar com energia mágica.
#
# Hoje, Akashi deve encontrar o professor Eldrin na sala de feitiçaria para uma avaliação inicial. Dizem que Eldrin é austero e exigente, mas justo. Com o coração acelerado e um brilho de determinação em seus olhos, Akashi se prepara para provar seu valor e aprender os segredos que Arcanis guarda. Qual será a sua jornada na busca pelo conhecimento arcano?
# Akashi:  !aparencia
# Imagem 1: https://oaidalleapiprodscus.blob.core.windows.net/private/org-mmkcAJ6hr4j6sR3rrJKXf4TI/user-qFA59LtwNCmJGdGpubZQq1X7/img-zVXm6YYWasCXA8kLXXgbdPR5.png?st=2025-04-09T13%3A13%3A08Z&se=2025-04-09T15%3A13%3A08Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-09T10%3A16%3A56Z&ske=2025-04-10T10%3A16%3A56Z&sks=b&skv=2024-08-04&sig=/%2BLB2gaUgby8RfsjcyrNUBbbPnVtfuqc7XrF6mgsKp0%3D
# Akashi:  !cena
# Imagem 1: https://oaidalleapiprodscus.blob.core.windows.net/private/org-mmkcAJ6hr4j6sR3rrJKXf4TI/user-qFA59LtwNCmJGdGpubZQq1X7/img-Pc420TbxwYpyEh0pe9nnOQrf.png?st=2025-04-09T13%3A13%3A48Z&se=2025-04-09T15%3A13%3A48Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-09T12%3A12%3A52Z&ske=2025-04-10T12%3A12%3A52Z&sks=b&skv=2024-08-04&sig=A6nEgklB7tK13lizBqQH48NF4tZLdgyNdlQDGS/U050%3D
